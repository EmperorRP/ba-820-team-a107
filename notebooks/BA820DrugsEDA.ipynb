# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

drugs = pd.read_csv('/content/drive/MyDrive/M1 Project Proposal/data/drugs.csv')

# %% [markdown]
# This dataset contains historical record of pharmaceutical products and medicines evaluated by the European Medicines Agency (EMA). Each row represents a medicine that has gone through the evaluation & authorization process. There is data containing authorization status, chemical classification (atc_code), and special designations (orphan status, biosimilars).
#
# Stakeholders of this data are:
# * Pharmaceutical R&D Strategy Analysts
# * Pharmaceutical Drug Regulatory Officials
# * Healthcare Policy Makers
# * Public Health Researchers
#
# Data Types:
# * Categorical: category, authorization_status, marketing_authorisation_holder_company_name
# * Boolean Flags: orphan_medicine, condition_indication, patient_safety, additional_monitoring, generic, biosimilar, conditional_approval, exceptional_circumstances, accelerated_assessment.
#
# Notable features:
# * species: only used for veterinary drugs
# * Heavy skew towards "Human" drugs (~86%), and "Authorised" status (~79%)

# %%
display(drugs.head())
display(drugs.info())
# Out:
#   category medicine_name                                   therapeutic_area  \
# 0    human      Adcetris            Lymphoma, Non-Hodgkin;  Hodgkin Disease
# 1    human         Nityr                                       Tyrosinemias
# 2    human       Ebvallo                      Lymphoproliferative Disorders
# 3    human     Ronapreve                           COVID-19 virus infection
# 4    human      Cosentyx  Arthritis, Psoriatic;  Psoriasis;  Spondylitis...
#
#               common_name        active_substance  product_number  \
# 0     brentuximab vedotin     brentuximab vedotin            2455
# 1              nitisinone              nitisinone            4582
# 2           tabelecleucel           tabelecleucel            4577
# 3  casirivimab, imdevimab  casirivimab, imdevimab            5814
# 4             secukinumab             secukinumab            3729
#
#    patient_safety authorisation_status atc_code  additional_monitoring  ...  \
# 0           False           authorised  L01XC12                  False  ...
# 1           False           authorised  A16AX04                  False  ...
# 2           False           authorised      NaN                   True  ...
# 3           False           authorised    J06BD                   True  ...
# 4           False           authorised  L04AC10                  False  ...
#
#    marketing_authorisation_holder_company_name  \
# 0                            Takeda Pharma A/S
# 1           Cycle Pharmaceuticals (Europe) Ltd
# 2                      Pierre Fabre Medicament
# 3                     Roche Registration GmbH
# 4                   Novartis Europharm Limited
#
#                          pharmacotherapeutic_group  date_of_opinion  \
# 0                            Antineoplastic agents       2012-07-19
# 1  Other alimentary tract and metabolism products,       2018-05-31
# 2                                              NaN       2022-10-13
# 3                 Immune sera and immunoglobulins,       2021-11-11
# 4                               Immunosuppressants       2014-11-20
#
#    decision_date  revision_number  \
# 0     2022-11-17             34.0
# 1     2023-03-10              4.0
# 2     2023-03-09              2.0
# 3     2023-02-24              3.0
# 4     2023-01-26             30.0
#
#                                 condition_indication species  \
# 0  Hodgkin lymphomaAdcetris is indicated for adul...     NaN
# 1  Treatment of adult and paediatric patients wit...     NaN
# 2  Ebvallo is indicated as monotherapy for treatm...     NaN
# 3  Ronapreve is indicated for:Treatment of COVID-...     NaN
# 4  Plaque psoriasisCosentyx is indicated for the ...     NaN
#
#         first_published         revision_date  \
# 0  2018-07-25T13:58:00Z  2023-03-13T11:52:00Z
# 1  2018-07-26T14:20:00Z  2023-03-10T17:29:00Z
# 2  2022-10-12T16:13:00Z  2023-03-10T13:40:00Z
# 3  2021-11-12T16:30:00Z  2023-03-10T12:29:00Z
# 4  2018-06-07T11:59:00Z  2023-03-09T18:53:00Z
#
#                                                  url
# 0  https://www.ema.europa.eu/en/medicines/human/E...
# 1  https://www.ema.europa.eu/en/medicines/human/E...
# 2  https://www.ema.europa.eu/en/medicines/human/E...
# 3  https://www.ema.europa.eu/en/medicines/human/E...
# 4  https://www.ema.europa.eu/en/medicines/human/E...
#
# [5 rows x 28 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1988 entries, 0 to 1987
# Data columns (total 28 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   category                                     1988 non-null   object
#  1   medicine_name                                1988 non-null   object
#  2   therapeutic_area                             1703 non-null   object
#  3   common_name                                  1984 non-null   object
#  4   active_substance                             1987 non-null   object
#  5   product_number                               1988 non-null   int64
#  6   patient_safety                               1988 non-null   bool
#  7   authorisation_status                         1987 non-null   object
#  8   atc_code                                     1960 non-null   object
#  9   additional_monitoring                        1988 non-null   bool
#  10  generic                                      1988 non-null   bool
#  11  biosimilar                                   1988 non-null   bool
#  12  conditional_approval                         1988 non-null   bool
#  13  exceptional_circumstances                    1988 non-null   bool
#  14  accelerated_assessment                       1988 non-null   bool
#  15  orphan_medicine                              1988 non-null   bool
#  16  marketing_authorisation_date                 1928 non-null   object
#  17  date_of_refusal_of_marketing_authorisation   75 non-null     object
#  18  marketing_authorisation_holder_company_name  1984 non-null   object
#  19  pharmacotherapeutic_group                    1954 non-null   object
#  20  date_of_opinion                              1209 non-null   object
#  21  decision_date                                1943 non-null   object
#  22  revision_number                              1892 non-null   float64
#  23  condition_indication                         1976 non-null   object
#  24  species                                      279 non-null    object
#  25  first_published                              1988 non-null   object
#  26  revision_date                                1959 non-null   object
#  27  url                                          1988 non-null   object
# dtypes: bool(8), float64(1), int64(1), object(18)
# memory usage: 326.3+ KB
# None

# %%
import matplotlib.pyplot as plt
import seaborn as sns

flags = ['orphan_medicine', 'conditional_approval', 'accelerated_assessment',
         'exceptional_circumstances', 'biosimilar', 'generic']
flag_counts = drugs[flags].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
correlation_matrix = drugs[flags].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Between Regulatory Flags')
# Out:
# Text(0.5, 1.0, 'Correlation Between Regulatory Flags')

# %%
date_cols = ['marketing_authorisation_date', 'decision_date', 'first_published']
for col in date_cols:
    drugs[col] = pd.to_datetime(drugs[col], errors='coerce', utc=True)

drugs['approval_year'] = drugs['marketing_authorisation_date'].dt.year

plt.figure(figsize=(10, 6))
drugs['approval_year'].value_counts().sort_index().plot(kind='line', marker='o', color='teal')
plt.title('Volume of Drug Approvals Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Approvals')
plt.grid(True, linestyle='--', alpha=0.7)

# %%
drugs['marketing_authorisation_date'].head(10)
# Out:
# 0   2012-10-25 00:00:00+00:00
# 1   2018-07-26 00:00:00+00:00
# 2   2022-12-16 00:00:00+00:00
# 3   2021-11-12 00:00:00+00:00
# 4   2015-01-14 00:00:00+00:00
# 5   2012-02-16 00:00:00+00:00
# 6   2021-11-15 00:00:00+00:00
# 7   2010-07-27 00:00:00+00:00
# 8   2007-06-29 00:00:00+00:00
# 9   2015-07-28 00:00:00+00:00
# Name: marketing_authorisation_date, dtype: datetime64[ns, UTC]

# %%
categories = drugs['category'].value_counts()
plt.figure(figsize=(5, 3))
sns.catplot(categories, kind = 'bar')
plt.xlabel('Category')
plt.ylabel('Number of Drugs')
plt.title('Distribution of Drug Categories')
# Out:
# Text(0.5, 1.0, 'Distribution of Drug Categories')

# %%
# --- 2. The Q4 Insight: Who is "Cross-Over"? ---
# Let's look at the Top 15 companies and color-code their portfolio
top_holders = drugs['marketing_authorisation_holder_company_name'].value_counts().head(15).index

plt.figure(figsize=(10, 6))
sns.countplot(y='marketing_authorisation_holder_company_name',
              data=drugs[drugs['marketing_authorisation_holder_company_name'].isin(top_holders)],
              hue='category',
              order=top_holders,
              palette='Set2')
plt.title('Portfolio Split: Do Big Pharmas have Vet Departments?')
plt.xlabel('Count of Drugs')
plt.ylabel('Company')
plt.legend(title='Category', loc='lower right')
plt.tight_layout()
plt.savefig('company_portfolio_split.png')

# --- 3. The "Scientific" Overlap ---
# Do they use the same chemicals?
human_subs = set(drugs[drugs['category'] == 'human']['active_substance'].dropna().str.lower())
vet_subs = set(drugs[drugs['category'] == 'veterinary']['active_substance'].dropna().str.lower())
overlap = human_subs.intersection(vet_subs)

print(f"Companies in both sectors: {len(set(drugs[drugs['category']=='human']['marketing_authorisation_holder_company_name']).intersection(set(drugs[drugs['category']=='veterinary']['marketing_authorisation_holder_company_name'])))}")
print(f"Active Substances in both sectors: {len(overlap)}")
print(f"Example crossovers: {list(overlap)[:5]}")
# Out:
# Companies in both sectors: 3
# Active Substances in both sectors: 7
# Example crossovers: ['masitinib mesilate', 'dibotermin alfa', 'dexmedetomidine hydrochloride', 'fentanyl', 'pregabalin']
